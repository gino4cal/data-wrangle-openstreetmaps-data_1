# %%
def get_db(db_name):
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client[db_name]
    return db

def make_pipeline():
    # sorted frequency of cuisine types
    '''pipeline = [{'$match':{'$or':[{'amenity':'fast_food'},{'amenity':'restaurant'}, {'amenity':'cafe'}],'cuisine':{'$exists':1}}},
                {'$group': {'_id': '$cuisine',
                            'count':{'$sum': 1}}},
                {'$sort':{'count':-1}},
                {'$limit': 25}]'''
    
    #rank highest to lowest in population              
    
    '''pipeline = [{'$match':{'population':{'$exists':1}}},
                {'$project': {'_id': '$name',
                            'population':'$population'}},  
                {'$group':{'_id':'$_id',
                           
                           'population':{'$max':'$population'}}},
                {'$sort':{'population':-1}}]'''
    
    #the highest frequency of amenities
    '''pipeline = [{'$match':{'amenity':{'$exists':1}}},
                {'$group': {'_id': '$amenity',
                            'count':{'$sum': 1}}},
                {'$sort':{'count':-1}}]'''
    
    #frequency of users
    '''pipeline = [{'$match':{'created.user':{'$exists':1}}},
                {'$group': {'_id': '$created.user',
                            'count':{'$sum': 1}}},
                {'$sort':{'count':-1}}]'''
    
    #show records where amenity is blank but name has " Park". 
    pipeline = [{'$match':{'name':{'$regex':' Park$'},
                           'type':'node',
                           'amenity':{'$exists':0}}},
                {'$project':{'_id': 0,
                             'name':'$name',
                             'user':'$created.user',
                             'gnis_feature':'$gnis.feature_id'}}]
                
    
    
                
    
                
    
                             
                
    return pipeline

def aggregate(db, pipeline):
    result = db.oxnard.aggregate(pipeline)
    return result

if __name__ == '__main__':
    db = get_db('map')
    
    pipeline = make_pipeline()
    result = aggregate(db, pipeline)
    import pprint
    pprint.pprint(result)
# Out:
# {u'ok': 1.0,
#  u'result': [{u'name': u'Royal Palms Mobile Home Park',
#               u'user': u'davidearl'},
#              {u'name': u'Newbury Park', u'user': u'davidearl'},
#              {u'name': u'Lamplighter Mobile Home Park', u'user': u'Bribunk'},
#              {u'name': u'Conejo Valley Trailer Park', u'user': u'davidearl'},
#              {u'name': u'Rancho Santa Paul Mobile Home Park',
#               u'user': u'davidearl'},
#              {u'name': u'Foster Park', u'user': u'davidearl'},
#              {u'name': u'Pleasant Valley Mobile Home Park',
#               u'user': u'davidearl'},
#              {u'gnis_feature': u'240056',
#               u'name': u'Camarillo Oak Grove County Park',
#               u'user': u'iandees'},
#              {u'gnis_feature': u'242929',
#               u'name': u'Grant Memorial Park',
#               u'user': u'iandees'},
#              {u'gnis_feature': u'245917',
#               u'name': u'Mill Park',
# ...
